# %% [markdown]
# # CycleGAN – Photo → Cartoon
#
# • True cycle consistency
# • Identity loss
# • 50 epochs
# • Loss visualization
# • Inference after training

# %%
# !pip install torch torchvision tqdm pillow matplotlib kaggle
# Out:
# Requirement already satisfied: torch in d:\program files\pyhton 3.12.10\lib\site-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in d:\program files\pyhton 3.12.10\lib\site-packages (0.21.0+cu124)
# Requirement already satisfied: tqdm in d:\program files\pyhton 3.12.10\lib\site-packages (4.67.1)
# Requirement already satisfied: pillow in d:\program files\pyhton 3.12.10\lib\site-packages (12.0.0)
# Requirement already satisfied: matplotlib in d:\program files\pyhton 3.12.10\lib\site-packages (3.10.8)
# Requirement already satisfied: kaggle in d:\program files\pyhton 3.12.10\lib\site-packages (1.8.2)
# Requirement already satisfied: filelock in d:\program files\pyhton 3.12.10\lib\site-packages (from torch) (3.20.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\program files\pyhton 3.12.10\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: networkx in d:\program files\pyhton 3.12.10\lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in d:\program files\pyhton 3.12.10\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in d:\program files\pyhton 3.12.10\lib\site-packages (from torch) (2025.12.0)
# Requirement already satisfied: setuptools in d:\program files\pyhton 3.12.10\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: sympy==1.13.1 in d:\program files\pyhton 3.12.10\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\program files\pyhton 3.12.10\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in d:\program files\pyhton 3.12.10\lib\site-packages (from torchvision) (2.3.5)
# Requirement already satisfied: colorama in c:\users\bedi\appdata\roaming\python\python312\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in d:\program files\pyhton 3.12.10\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\program files\pyhton 3.12.10\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\program files\pyhton 3.12.10\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\program files\pyhton 3.12.10\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\bedi\appdata\roaming\python\python312\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pyparsing>=3 in d:\program files\pyhton 3.12.10\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\bedi\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: black>=24.10.0 in d:\program files\pyhton 3.12.10\lib\site-packages (from kaggle) (25.12.0)
# Requirement already satisfied: bleach in d:\program files\pyhton 3.12.10\lib\site-packages (from kaggle) (6.3.0)
# Requirement already satisfied: kagglesdk in d:\program files\pyhton 3.12.10\lib\site-packages (from kaggle) (0.1.13)
# Requirement already satisfied: mypy>=1.15.0 in d:\program files\pyhton 3.12.10\lib\site-packages (from kaggle) (1.19.1)
# Requirement already satisfied: protobuf in d:\program files\pyhton 3.12.10\lib\site-packages (from kaggle) (6.33.2)
# Requirement already satisfied: python-slugify in d:\program files\pyhton 3.12.10\lib\site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in d:\program files\pyhton 3.12.10\lib\site-packages (from kaggle) (2.32.5)
# Requirement already satisfied: six>=1.10 in c:\users\bedi\appdata\roaming\python\python312\site-packages (from kaggle) (1.17.0)
# Requirement already satisfied: types-requests in d:\program files\pyhton 3.12.10\lib\site-packages (from kaggle) (2.32.4.20250913)
# Requirement already satisfied: types-tqdm in d:\program files\pyhton 3.12.10\lib\site-packages (from kaggle) (4.67.0.20250809)
# Requirement already satisfied: urllib3>=1.15.1 in d:\program files\pyhton 3.12.10\lib\site-packages (from kaggle) (2.6.2)
# Requirement already satisfied: click>=8.0.0 in d:\program files\pyhton 3.12.10\lib\site-packages (from black>=24.10.0->kaggle) (8.3.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in d:\program files\pyhton 3.12.10\lib\site-packages (from black>=24.10.0->kaggle) (1.1.0)
# Requirement already satisfied: pathspec>=0.9.0 in d:\program files\pyhton 3.12.10\lib\site-packages (from black>=24.10.0->kaggle) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in c:\users\bedi\appdata\roaming\python\python312\site-packages (from black>=24.10.0->kaggle) (4.5.1)
# Requirement already satisfied: pytokens>=0.3.0 in d:\program files\pyhton 3.12.10\lib\site-packages (from black>=24.10.0->kaggle) (0.3.0)
# Requirement already satisfied: librt>=0.6.2 in d:\program files\pyhton 3.12.10\lib\site-packages (from mypy>=1.15.0->kaggle) (0.7.4)
# Requirement already satisfied: webencodings in d:\program files\pyhton 3.12.10\lib\site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\program files\pyhton 3.12.10\lib\site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: text-unidecode>=1.3 in d:\program files\pyhton 3.12.10\lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\program files\pyhton 3.12.10\lib\site-packages (from requests->kaggle) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\program files\pyhton 3.12.10\lib\site-packages (from requests->kaggle) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in d:\program files\pyhton 3.12.10\lib\site-packages (from requests->kaggle) (2025.11.12)
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
os.environ['KAGGLE_USERNAME'] = 'YOUR_KAGGLE_USERNAME'
os.environ['KAGGLE_KEY'] = 'YOUR_KAGGLE_API_KEY'

# %%
# !kaggle datasets download -d jessicali9530/celeba-dataset
# !kaggle datasets download -d arnaud58/photo2cartoon
# !unzip -q celeba-dataset.zip
# !unzip -q photo2cartoon.zip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/jessicali9530/celeba-dataset
# License(s): other
# celeba-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)
# Dataset URL: https://www.kaggle.com/datasets/arnaud58/photo2cartoon
# License(s): CC0-1.0
# photo2cartoon.zip: Skipping, found more recently modified local copy (use --force to force download)
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ## Dataset Preparation (SAFE)

# %%
import os
from PIL import Image
from tqdm import tqdm
import random

# Buat folder tujuan
os.makedirs('dataset/trainA', exist_ok=True)
os.makedirs('dataset/trainB', exist_ok=True)

# --- 1. PROSES REAL FACES (Target: 4000) ---
real_src = 'img_align_celeba'  # Pastikan path ini sesuai dengan folder hasil unzip kamu
output_real = 'dataset/trainA'
target_real = 4000

# Cek jumlah file yang sudah ada
current_real = len(os.listdir(output_real))

if current_real >= target_real:
    print(f"✅ Real faces sudah ada ({current_real} files). Skip processing.")
else:
    print(f"🔄 Memproses Real faces... (Target: {target_real})")
    real_imgs = os.listdir(real_src)
    
    # Ambil sample sejumlah target
    selected_real = random.sample(real_imgs, min(target_real, len(real_imgs)))
    
    for img in tqdm(selected_real, desc='Real faces'):
        try:
            # Cek apakah file sudah ada biar tidak ditimpa (opsional, tapi aman)
            dest_path = os.path.join(output_real, img)
            if not os.path.exists(dest_path):
                im = Image.open(os.path.join(real_src, img)).convert('RGB').resize((256, 256))
                im.save(dest_path)
        except Exception as e:
            pass # Skip jika ada gambar error

# --- 2. PROSES CARTOON FACES (Target: 3000) ---
cartoon_src = 'trainB'
output_cartoon = 'dataset/trainB'
target_cartoon = 3000

# Cek jumlah file yang sudah ada
current_cartoon = len(os.listdir(output_cartoon))

if current_cartoon >= target_cartoon:
    print(f"✅ Cartoon faces sudah ada ({current_cartoon} files). Skip processing.")
else:
    print(f"🔄 Memproses Cartoon faces... (Target: {target_cartoon})")
    cartoon_imgs = os.listdir(cartoon_src)
    
    # Ambil sample sejumlah target
    selected_cartoon = random.sample(cartoon_imgs, min(target_cartoon, len(cartoon_imgs)))
    
    for img in tqdm(selected_cartoon, desc='Cartoon faces'):
        try:
            dest_path = os.path.join(output_cartoon, img)
            if not os.path.exists(dest_path):
                im = Image.open(os.path.join(cartoon_src, img)).convert('RGB').resize((256, 256))
                im.save(dest_path)
        except Exception as e:
            pass

print("\n🎉 Dataset Preparation Selesai!")
# Out:
# Real faces: 100%|██████████| 4000/4000 [00:35<00:00, 112.68it/s]
# Cartoon faces: 100%|██████████| 194/194 [00:02<00:00, 93.01it/s]

# %% [markdown]
# ## Dataset Loader

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

class UnpairedDataset(Dataset):
    def __init__(self, A, B):
        self.A = os.listdir(A)
        self.B = os.listdir(B)
        self.A_dir = A
        self.B_dir = B
        self.tf = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
        ])
    def __len__(self): return max(len(self.A), len(self.B))
    def __getitem__(self, i):
        a = Image.open(os.path.join(self.A_dir, self.A[i % len(self.A)])).convert('RGB')
        b = Image.open(os.path.join(self.B_dir, random.choice(self.B))).convert('RGB')
        return self.tf(a), self.tf(b)

# %% [markdown]
# ## CycleGAN Model (Correct Formulation)

# %%
import torch.nn as nn

class ResBlock(nn.Module):
    def __init__(self, c):
        super().__init__()
        self.b = nn.Sequential(
            nn.ReflectionPad2d(1), nn.Conv2d(c,c,3), nn.InstanceNorm2d(c), nn.ReLU(),
            nn.ReflectionPad2d(1), nn.Conv2d(c,c,3), nn.InstanceNorm2d(c)
        )
    def forward(self,x): return x + self.b(x)

class Generator(nn.Module):
    def __init__(self):
        super().__init__()
        layers = [nn.ReflectionPad2d(3), nn.Conv2d(3,64,7), nn.InstanceNorm2d(64), nn.ReLU()]
        layers += [nn.Conv2d(64,128,3,2,1), nn.InstanceNorm2d(128), nn.ReLU()]
        layers += [nn.Conv2d(128,256,3,2,1), nn.InstanceNorm2d(256), nn.ReLU()]
        for _ in range(9): layers += [ResBlock(256)]
        layers += [nn.ConvTranspose2d(256,128,3,2,1,1), nn.InstanceNorm2d(128), nn.ReLU()]
        layers += [nn.ConvTranspose2d(128,64,3,2,1,1), nn.InstanceNorm2d(64), nn.ReLU()]
        layers += [nn.ReflectionPad2d(3), nn.Conv2d(64,3,7), nn.Tanh()]
        self.net = nn.Sequential(*layers)
    def forward(self,x): return self.net(x)

class Discriminator(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(3,64,4,2,1), nn.LeakyReLU(0.2),
            nn.Conv2d(64,128,4,2,1), nn.InstanceNorm2d(128), nn.LeakyReLU(0.2),
            nn.Conv2d(128,256,4,2,1), nn.InstanceNorm2d(256), nn.LeakyReLU(0.2),
            nn.Conv2d(256,1,4,1,1)
        )
    def forward(self,x): return self.net(x)

# %% [markdown]
# ## Training – 50 Epochs

# %%
from tqdm import tqdm
import torch
import matplotlib.pyplot as plt
from IPython.display import clear_output  # Untuk update grafik secara live

# --- 1. SETUP VARIABEL LOSS ---
# Cek apakah variabel sudah ada (supaya kalau resume, grafik lama tidak hilang)
if 'G_losses' not in globals(): G_losses = []
if 'D_losses' not in globals(): D_losses = []

# --- 2. LOAD MODEL TERAKHIR (SAFETY) ---
try:
    print("Memuat model terakhir...")
    # Pastikan file .pth ada sebelum diload
    if os.path.exists('G_photo2cartoon.pth'):
        G_AB.load_state_dict(torch.load('G_photo2cartoon.pth', map_location=device))
        print("✅ Lanjut training dari checkpoint terakhir!")
    else:
        print("⚠️ File checkpoint tidak ditemukan, mulai dari awal (atau memory lama).")
except Exception as e:
    print(f"Info: {e}")

# --- 3. TRAINING LOOP DENGAN LIVE GRAPH ---
# Ubah range sesuai kebutuhan (misal sisa 7 epoch lagi)
for epoch in range(10): 
    g_epoch = 0
    d_epoch = 0 # Tambahan variabel untuk rata-rata Loss Discriminator
    
    # Setup Loading Bar
    loop = tqdm(dl, desc=f"Epoch {epoch}/10")
    
    for realA, realB in loop:
        realA, realB = realA.to(device), realB.to(device)

        # --- A. TRAIN GENERATOR ---
        fakeB = G_AB(realA)
        fakeA = G_BA(realB)
        recA = G_BA(fakeB)
        recB = G_AB(fakeA)
        
        loss_id = identity(G_AB(realB), realB)*5 + identity(G_BA(realA), realA)*5
        loss_cycle = cycle(recA, realA)*10 + cycle(recB, realB)*10
        loss_gan = gan(D_B(fakeB), torch.ones_like(D_B(fakeB))) + gan(D_A(fakeA), torch.ones_like(D_A(fakeA)))
        
        loss_G = loss_id + loss_cycle + loss_gan
        opt_G.zero_grad(); loss_G.backward(); opt_G.step()
        
        # --- B. TRAIN DISCRIMINATOR ---
        loss_D = (gan(D_A(realA), torch.ones_like(D_A(realA))) + gan(D_A(fakeA.detach()), torch.zeros_like(D_A(fakeA))) + 
                  gan(D_B(realB), torch.ones_like(D_B(realB))) + gan(D_B(fakeB.detach()), torch.zeros_like(D_B(fakeB)))) * 0.5
        
        opt_D.zero_grad(); loss_D.backward(); opt_D.step()
        
        # --- C. RECORD DATA ---
        g_epoch += loss_G.item()
        d_epoch += loss_D.item() # Catat loss D

        # Update angka loss di loading bar (Live Validation)
        loop.set_postfix(G_loss=loss_G.item(), D_loss=loss_D.item())

    # --- SETIAP AKHIR EPOCH ---
    
    # 1. Simpan Rata-rata Loss Epoch ini
    avg_G_loss = g_epoch/len(dl)
    avg_D_loss = d_epoch/len(dl)
    G_losses.append(avg_G_loss)
    D_losses.append(avg_D_loss)

    # 2. Save Model Otomatis
    torch.save(G_AB.state_dict(), 'G_photo2cartoon.pth')
    
    # 3. UPDATE GRAFIK (LIVE PLOT)
    clear_output(wait=True) # Hapus output lama
    
    plt.figure(figsize=(10, 5))
    plt.title(f"Training Loss - Epoch {epoch}")
    plt.plot(G_losses, label="Generator Loss (G)", color="blue")
    plt.plot(D_losses, label="Discriminator Loss (D)", color="orange")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    plt.show()
    
    print(f"💾 Model tersimpan di akhir Epoch {epoch}")
    print(f"📊 Stats: G_Loss={avg_G_loss:.4f} | D_Loss={avg_D_loss:.4f}")
# Out:
# 💾 Model tersimpan di akhir Epoch 1
# 📊 Stats: G_Loss=3.5682 | D_Loss=0.2902
# Epoch 2/10:   9%|▉         | 368/4000 [03:34<35:13,  1.72it/s, D_loss=0.334, G_loss=2.9]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 55
#      52 opt_D.zero_grad(); loss_D.backward(); opt_D.step()
#      54 # --- C. RECORD DATA ---
# ---> 55 g_epoch += loss_G.item()
#      56 d_epoch += loss_D.item() # Catat loss D
#      58 # Update angka loss di loading bar (Live Validation)
#
# KeyboardInterrupt:

# %%
# --- EMERGENCY SAVE ---
# Kode ini menyelamatkan progress yang ada di memori RAM ke Hardisk
try:
    torch.save(G_AB.state_dict(), 'G_photo2cartoon_emergency.pth')
    print("✅ AMAN! Model berhasil diselamatkan dengan nama 'G_photo2cartoon_emergency.pth'")
except NameError:
    print("❌ Gawat, variabel model hilang. Apakah kamu tidak sengaja restart kernel?")
# Out:
# ✅ AMAN! Model berhasil diselamatkan dengan nama 'G_photo2cartoon_emergency.pth'

# %% [markdown]
# ## Inference – Upload ANY Image (NO RETRAINING)

# %%
img_path = '5617.jpeg'

img = Image.open(img_path).convert('RGB').resize((256,256))
tf = transforms.Compose([
    transforms.ToTensor(), transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
])

G_AB.load_state_dict(torch.load('G_photo2cartoon.pth', map_location=device))
G_AB.eval()

with torch.no_grad():
    out = G_AB(tf(img).unsqueeze(0).to(device))[0]

out = (out.cpu()*0.5+0.5).permute(1,2,0).numpy()
plt.imshow(out); plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(255.5), np.float64(255.5), np.float64(-0.5))

# %%
import os

filename = 'G_photo2cartoon.pth'

# Cek apakah file sudah terbentuk di folder projectmu
if os.path.exists(filename):
    print(f"✅ HORE! File model '{filename}' sudah berhasil tersimpan di laptopmu.")
    print(f"Lokasinya ada di: {os.getcwd()}")
else:
    print(f"❌ File '{filename}' belum ditemukan. Sepertinya training belum selesai atau error.")
# Out:
# ✅ HORE! File model 'G_photo2cartoon.pth' sudah berhasil tersimpan di laptopmu.
# Lokasinya ada di: d:\Program Files\Tugas GAN

# %%
import torch
import torchvision.transforms as transforms
from PIL import Image
import matplotlib.pyplot as plt
import os

# 1. Define the specific path to your image
img_path = 'image_1.jpg'

# Check if the image actually exists there
if not os.path.exists(img_path):
    print(f"ERROR: The image was not found at {img_path}")
    print("Please ensure you have uploaded the image to the main Colab content folder.")
else:
    print(f"Processing image: {img_path}")

    # 2. Load and Preprocess image
    # Resize to 256x256 matches typical CycleGAN training size
    img = Image.open(img_path).convert('RGB').resize((256, 256))

    # Define the same normalization used during training (-1 to 1 range)
    tf = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

    # 3. Load pre-trained weights
    # Ensure G_AB is already defined from your training cells!
    if 'G_AB' not in globals():
        print("ERROR: Generator 'G_AB' is not defined. Run your model definition cells first.")
    else:
        try:
            # map_location ensures weights load even if you switched from GPU back to CPU
            G_AB.load_state_dict(torch.load('G_photo2cartoon.pth', map_location=device))
            print("Model weights loaded successfully.")

            # Set to evaluation mode (crucial for layers like BatchNorm/Dropout)
            G_AB.eval()

            # 4. Run Inference
            with torch.no_grad():
                # Preprocess -> Add batch dim (unsqueeze) -> Send to device -> Run model -> Get first result ([0])
                input_tensor = tf(img).unsqueeze(0).to(device)
                out_tensor = G_AB(input_tensor)[0]

            # 5. Post-process and Display
            # Denormalize from (-1, 1) back to (0, 1) range
            out_img = (out_tensor.cpu() * 0.5 + 0.5)
            # Rearrange dimensions from pytorch (C,H,W) to matplotlib (H,W,C)
            out_img = out_img.permute(1, 2, 0).numpy()

            plt.figure(figsize=(8,4))

            plt.subplot(1,2,1)
            plt.title("Original")
            plt.imshow(img)
            plt.axis('off')

            plt.subplot(1,2,2)
            plt.title("Cartoon Style")
            plt.imshow(out_img)
            plt.axis('off')

            plt.show()

        except FileNotFoundError:
            print("ERROR: 'G_photo2cartoon.pth' not found. Make sure you have trained and saved the model weights.")
# Out:
# ERROR: The image was not found at image_1.jpg
# Please ensure you have uploaded the image to the main Colab content folder.
